# %%
#Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#DataSet 1
la_df = pd.read_csv("./housing.csv")
la_df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
la_df.info
# Out:
# <bound method DataFrame.info of        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
new_la_df = la_df[["ocean_proximity", "longitude", "latitude", "housing_median_age", "households", "median_income",
                            "median_house_value"]]
new_la_df
# Out:
#       ocean_proximity  longitude  latitude  housing_median_age  households  \
# 0            NEAR BAY    -122.23     37.88                41.0       126.0
# 1            NEAR BAY    -122.22     37.86                21.0      1138.0
# 2            NEAR BAY    -122.24     37.85                52.0       177.0
# 3            NEAR BAY    -122.25     37.85                52.0       219.0
# 4            NEAR BAY    -122.25     37.85                52.0       259.0
# ...               ...        ...       ...                 ...         ...
# 20635          INLAND    -121.09     39.48                25.0       330.0
# 20636          INLAND    -121.21     39.49                18.0       114.0
# 20637          INLAND    -121.22     39.43                17.0       433.0
# 20638          INLAND    -121.32     39.43                18.0       349.0
# 20639          INLAND    -121.24     39.37                16.0       530.0
#
#        median_income  median_house_value
# ...

# %%
region_df = new_la_df[["ocean_proximity", "median_house_value"]]

clean_df = region_df.loc[(region_df["ocean_proximity"] == "NEAR BAY")]
clean_df
# Out:
#       ocean_proximity  median_house_value
# 0            NEAR BAY            452600.0
# 1            NEAR BAY            358500.0
# 2            NEAR BAY            352100.0
# 3            NEAR BAY            341300.0
# 4            NEAR BAY            342200.0
# ...               ...                 ...
# 19067        NEAR BAY            297600.0
# 19068        NEAR BAY            208000.0
# 19069        NEAR BAY            262300.0
# 19077        NEAR BAY            213200.0
# 19104        NEAR BAY            246300.0
#
# [2290 rows x 2 columns]

# %%
clean_df.plot('ocean_proximity', 'median_house_value', kind='bar', figsize=(20,4), rot=45)
# Out:
# <AxesSubplot:xlabel='ocean_proximity'>

# %%
clean_df.plot('median_house_value', 'ocean_proximity', kind='scatter', figsize=(20,4), rot=45)
# Out:
# <AxesSubplot:xlabel='median_house_value', ylabel='ocean_proximity'>

# %%
#DataSet2
prev_df = pd.read_csv("./USSTHPI.csv")
prev_df.head(6)
# Out:
#          DATE  USSTHPI
# 0  2006-01-01   366.21
# 1  2006-04-01   369.95
# 2  2006-07-01   373.00
# 3  2006-10-01   376.82
# 4  2007-01-01   378.20
# 5  2007-04-01   377.93

# %%
prev_df.plot('DATE', 'USSTHPI', kind='bar', figsize=(10,5), rot=45)
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
prev_df.plot('DATE', 'USSTHPI', kind='scatter', figsize=(10,5), rot=45)
# Out:
# <AxesSubplot:xlabel='DATE', ylabel='USSTHPI'>

# %%
#DataSet3
prev2_df = pd.read_csv("./CSUSHPISA.csv")
prev2_df.head(6)
# Out:
#          DATE  CSUSHPISA
# 0  2006-01-01    182.325
# 1  2006-02-01    183.292
# 2  2006-03-01    184.372
# 3  2006-04-01    184.335
# 4  2006-05-01    184.162
# 5  2006-06-01    183.514

# %%
prev2_df.plot('DATE', 'CSUSHPISA', kind='bar', figsize=(20,5), rot=45)
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
prev2_df.plot('DATE', 'CSUSHPISA', kind='scatter', figsize=(20,5), rot=45)
# Out:
# <AxesSubplot:xlabel='DATE', ylabel='CSUSHPISA'>

# %%
prev3_df = pd.read_csv("./HPIPONM226S.csv")
prev3_df.head(6)
# Out:
#          DATE  HPIPONM226S
# 0  2006-01-01       220.39
# 1  2006-02-01       220.84
# 2  2006-03-01       221.66
# 3  2006-04-01       222.08
# 4  2006-05-01       222.72
# 5  2006-06-01       222.66

# %%
prev3_df.plot('DATE', 'HPIPONM226S', kind='bar', figsize=(20,5), rot=45)
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
prev3_df.plot('DATE', 'HPIPONM226S', kind='scatter', figsize=(20,5), rot=45)
# Out:
# <AxesSubplot:xlabel='DATE', ylabel='HPIPONM226S'>

# %%
#Merge DataSets
prev_data = "./USSTHPI.csv"
prev2_data = "./CSUSHPISA.csv"
prev3_data = "./HPIPONM226S.csv"

prev_data_df = pd.read_csv(prev_data)
prev2_data_df = pd.read_csv(prev2_data)
prev3_data_df = pd.read_csv(prev3_data)

# %%
combined_data_df = pd.merge(prev_data_df, prev2_data_df, 
                            how= 'inner', on='DATE')

combined_data_df.head(6)
# Out:
#          DATE  USSTHPI  CSUSHPISA
# 0  2006-01-01   366.21    182.325
# 1  2006-04-01   369.95    184.335
# 2  2006-07-01   373.00    183.069
# 3  2006-10-01   376.82    183.208
# 4  2007-01-01   378.20    184.523
# 5  2007-04-01   377.93    183.019

# %%
combined_data_df = pd.merge(combined_data_df, prev3_data_df, 
                            how= 'inner', on='DATE')
combined_data_df
# Out:
#           DATE  USSTHPI  CSUSHPISA  HPIPONM226S
# 0   2006-01-01   366.21    182.325       220.39
# 1   2006-04-01   369.95    184.335       222.08
# 2   2006-07-01   373.00    183.069       222.59
# 3   2006-10-01   376.82    183.208       223.43
# 4   2007-01-01   378.20    184.523       224.94
# 5   2007-04-01   377.93    183.019       226.00
# 6   2007-07-01   373.71    179.105       223.05
# 7   2007-10-01   372.53    176.636       219.36
# 8   2008-01-01   369.82    173.140       214.81
# 9   2008-04-01   360.49    168.346       209.34
# 10  2008-07-01   349.15    163.554       203.88
# 11  2008-10-01   345.93    158.336       198.30
# 12  2009-01-01   348.47    151.523       195.98
# 13  2009-04-01   339.27    147.960       192.79
# 14  2009-07-01   330.30    148.384       191.80
# 15  2009-10-01   327.83    147.856       191.66
# 16  2010-01-01   323.90    147.409       190.41
# 17  2010-04-01   321.00    146.399       189.71
# 18  2010-07-01   324.04    144.944       186.50

# %%
#Table showing Specific Bank debts throughout the crisis & before
banking_data_df = pd.read_csv("./Copy of Enterprise_Share_of_Residential_Mortgage_Debt_Outstanding_1990_-_2010.csv")
banking_data_df.head()
# Out:
#   Unnamed: 0  Unnamed: 1  \
# 0        NaN         NaN
# 1        NaN         NaN
# 2        NaN  Fannie Mae
# 3       1990    $404,703
# 4       1991    $484,267
#
#   Total Mortgages Held or Securitized by Fannie Mae and Freddie Mac  \
# 0  as a Percentage of Residential Mortgage Debt O...
# 1                                                NaN
# 2                                        Freddie Mac
# 3                                           $338,217
# 4                                           $386,209
#
#              Unnamed: 3                             Unnamed: 4  Unnamed: 5  \
# 0                   NaN                                    NaN         NaN
# 1                   NaN                                    NaN         NaN
# 2  Combined Enterprises  Residential Mortgage Debt Outstanding         NaN
# 3              $742,920                             $2,893,729         NaN
# 4              $870,476                             $3,058,425         NaN
#
# ...

# %%
new_table = banking_data_df[["Unnamed: 1", "Total Mortgages Held or Securitized by Fannie Mae and Freddie Mac", 
                        "Unnamed: 3", "Unnamed: 4"]]
new_table.head(50)
# Out:
#                     Unnamed: 1  \
# 0                          NaN
# 1                          NaN
# 2                   Fannie Mae
# 3                     $404,703
# 4                     $484,267
# 5                     $582,563
# 6                     $662,167
# 7                     $708,402
# 8                     $766,741
# 9                     $835,225
# 10                    $895,816
# 11                  $1,051,658
# 12                  $1,203,086
# 13                  $1,316,844
# 14                  $1,579,398
# 15                  $1,840,218
# 16                  $2,209,388
# 17                  $2,325,256
# 18                  $2,336,807
# 19                  $2,506,482
# 20                  $2,846,812
# 21                  $3,081,655
# 22                  $3,202,041
# 23                  $3,156,192
# 24                         NaN
# 25                         NaN
# 26                         NaN
# 27                         NaN
# 28  Combined Enterprise Share
# ...
